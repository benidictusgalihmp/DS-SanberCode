# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:
#
# <h2>Univariate</h2>
#
# > merupakan metode analisis yang melibatkan satu (uni) variabel(variate) dengan mendefiniskan, me-summarize-kan, dan menganalisis pola dari satu variabel.
#
# Types: Frequency table, Bar Charts, Historgram, Pie Chart, Frequency Polygon
#
# <h2>Bivariate</h2>
#
# > merupakan metode analisis yang melibatkan dua (bi) variable (variate) dengan mencari insight dan relasi dari dua variabel.
#
# Types: Scatter plot, Linear Correlation, Chi-square, Z-test, T-test
#
# <h2>Multivariate</h2>
#
# > merupakan metode analisis yang melibatkan lebih dari dua (multi) variable (variate) dalam satu waktu atau bersamaan.
#
# Types: Cluster Analysis, Factor Analysis, Multiple Regression Analysis, Principal Component Analysis, Correspondence Analysis

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here
dftwo = df.dropna()
dftwo = dftwo.groupby(by='species').mean()
dftwo
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
# Create canvas
plt.figure(figsize=(12, 8))

# Modify df into a percentage number in string type
# @param    :   df with type int or float 
# @return   :   a string with '%' character
def number(df):
    return "{:.1f}%".format(df)

# Plotting data into pie plot and labels = index with percentage of each data
plt.pie(dftwo['flipper_length_mm'], labels=dftwo.index, autopct=lambda var: number(var))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create canvas
plt.figure(figsize=(12, 8))

# Plotting data into histogram plot
plt.hist(df['body_mass_g'])

# Change xlabel='Body_mass_g' and ylabel='Count'
plt.xlabel('Body_mass_g')
plt.ylabel('Count')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:
#
# - Proposi persebaran data rata-rata `flipper_length_mm` **setelah** mengelompokan dan menghilangkan nilai `NaN` **tertinggi** (mode) adalah `Gentoo` dengan 36.0% dan **terendah** adalah `Adelie` dengan 31.5%.
#
# - Proposi persebaran data `body_mass_g` **terberat** (mode) berada pada **rentang 3500 - 4000** dengan jumlah data **sekitar 60-70**.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here
# plotting dataframe
sns.catplot(x='sex', y='bill_length_mm', data=df, kind='bar')

# %%
# set figure or canvas size
sns.set({'figure.figsize':(13,8)})

# set axes style into white
sns.set_style('white')

# plotting dataframe
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', data=df, hue='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:
#
# - Pada grafik catplot nilai `bill_length_mm` untuk kategori `male` lebih banyak daripada kategori `female`.
# - Pada grafik scatterplot relasi antara `body_mass_g` dengan `flipper_length_mm` berbanding lurus/linear (Pada grafik terlihat persebaran titik-titiknya membentuk garis ke kanan yang menandakan nilai koefisien korelasinya positif) dan persebaran data `bill_length_mm` yang direpresentasikan dengan ketebalan warnanya juga merata
#
# > Rentang kekuatan relasi 2 data dari scatterplot sulit ditentukan karena tidak memiliki data angka absolut (Biasanya kekuatan dua relasi data dapat ditentukan melalui koefisien relasi)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here
# plotting dataframe
sns.pairplot(df)

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
